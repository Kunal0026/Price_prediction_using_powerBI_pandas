# %%
import pandas as pd

# %%
df = pd.read_csv(r"F:\work\Data_Cleaning\Mumbai_house\Mumbai House Prices File.csv")
df
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        bhk       type                              locality  area  price  \
# 0        3  Apartment   Lak And Hanware The Residency Tower   685    2.5
# 1        2  Apartment     Radheya Sai Enclave Building No 2   640  52.51
# 2        2  Apartment                         Romell Serene   610   1.73
# 3        2  Apartment  Soundlines Codename Urban Rainforest   876  59.98
# 4        2  Apartment                         Origin Oriana   659  94.11
# ...    ...        ...                                   ...   ...    ...
# 76033    3  Apartment                     Parinee Liva Roca  1527    7.0
# 76034    5  Apartment                     Parinee Liva Roca  3049   12.0
# ...

# %%
df.drop_duplicates()
# Out:
#        bhk       type                              locality  area  price  \
# 0        3  Apartment   Lak And Hanware The Residency Tower   685    2.5
# 1        2  Apartment     Radheya Sai Enclave Building No 2   640  52.51
# 2        2  Apartment                         Romell Serene   610   1.73
# 3        2  Apartment  Soundlines Codename Urban Rainforest   876  59.98
# 4        2  Apartment                         Origin Oriana   659  94.11
# ...    ...        ...                                   ...   ...    ...
# 76033    3  Apartment                     Parinee Liva Roca  1527    7.0
# 76034    5  Apartment                     Parinee Liva Roca  3049   12.0
# 76035    4  Apartment                         Lodha Seaview  3313   10.0
# 76036    2  Apartment                        Hubtown Serene  1305   4.25
# 76037    5  Apartment              Sunteck Signature Island  5200   25.0
#
#       price_unit                region              status      age
# ...

# %%
df.head(60)
# Out:
#     bhk               type                                           locality  \
# 0     3          Apartment                Lak And Hanware The Residency Tower
# 1     2          Apartment                  Radheya Sai Enclave Building No 2
# 2     2          Apartment                                      Romell Serene
# 3     2          Apartment               Soundlines Codename Urban Rainforest
# 4     2          Apartment                                      Origin Oriana
# 5     2          Apartment                       Bhoomi Simana Wing A Phase 1
# 6     5              Villa                                     Agami Estancia
# 7     3          Apartment                                    Sanghvi Infenia
# 8     1          Apartment                              Shubh Shreeji Heights
# 9     2          Apartment                         Aplite Greenstone Heritage
# 10    1   Studio Apartment                               A Plus Golden Corner
# ...

# %%
df['region'] = df['region'].str.strip("_")
df['region'] = df['region'].str.strip("/")
df['region'] = df['region'].str.strip("123")
df
# Out:
#        bhk       type                              locality  area  price  \
# 0        3  Apartment   Lak And Hanware The Residency Tower   685    2.5
# 1        2  Apartment     Radheya Sai Enclave Building No 2   640  52.51
# 2        2  Apartment                         Romell Serene   610   1.73
# 3        2  Apartment  Soundlines Codename Urban Rainforest   876  59.98
# 4        2  Apartment                         Origin Oriana   659  94.11
# ...    ...        ...                                   ...   ...    ...
# 76033    3  Apartment                     Parinee Liva Roca  1527    7.0
# 76034    5  Apartment                     Parinee Liva Roca  3049   12.0
# 76035    4  Apartment                         Lodha Seaview  3313   10.0
# 76036    2  Apartment                        Hubtown Serene  1305   4.25
# 76037    5  Apartment              Sunteck Signature Island  5200   25.0
#
#       price_unit                region              status      age
# ...

# %%
df.head(60)
# Out:
#     bhk               type                                           locality  \
# 0     3          Apartment                Lak And Hanware The Residency Tower
# 1     2          Apartment                  Radheya Sai Enclave Building No 2
# 2     2          Apartment                                      Romell Serene
# 3     2          Apartment               Soundlines Codename Urban Rainforest
# 4     2          Apartment                                      Origin Oriana
# 5     2          Apartment                       Bhoomi Simana Wing A Phase 1
# 6     5              Villa                                     Agami Estancia
# 7     3          Apartment                                    Sanghvi Infenia
# 8     1          Apartment                              Shubh Shreeji Heights
# 9     2          Apartment                         Aplite Greenstone Heritage
# 10    1   Studio Apartment                               A Plus Golden Corner
# ...

# %%
df['price'] = df['price'].str.strip("ab")
df['price'] = df['price'].str.strip("qw")
df
# Out:
#        bhk       type                              locality  area  price  \
# 0        3  Apartment   Lak And Hanware The Residency Tower   685    2.5
# 1        2  Apartment     Radheya Sai Enclave Building No 2   640  52.51
# 2        2  Apartment                         Romell Serene   610   1.73
# 3        2  Apartment  Soundlines Codename Urban Rainforest   876  59.98
# 4        2  Apartment                         Origin Oriana   659  94.11
# ...    ...        ...                                   ...   ...    ...
# 76033    3  Apartment                     Parinee Liva Roca  1527    NaN
# 76034    5  Apartment                     Parinee Liva Roca  3049    NaN
# 76035    4  Apartment                         Lodha Seaview  3313    NaN
# 76036    2  Apartment                        Hubtown Serene  1305    NaN
# 76037    5  Apartment              Sunteck Signature Island  5200    NaN
#
#       price_unit                region              status      age
# ...

# %%
df.head(60)
# Out:
#     bhk               type                                           locality  \
# 0     3          Apartment                Lak And Hanware The Residency Tower
# 1     2          Apartment                  Radheya Sai Enclave Building No 2
# 2     2          Apartment                                      Romell Serene
# 3     2          Apartment               Soundlines Codename Urban Rainforest
# 4     2          Apartment                                      Origin Oriana
# 5     2          Apartment                       Bhoomi Simana Wing A Phase 1
# 6     5              Villa                                     Agami Estancia
# 7     3          Apartment                                    Sanghvi Infenia
# 8     1          Apartment                              Shubh Shreeji Heights
# 9     2          Apartment                         Aplite Greenstone Heritage
# 10    1   Studio Apartment                               A Plus Golden Corner
# ...
